# %% [markdown]
# ### Visualizing Filters and Feature Maps for Deep Learning

# %% [markdown]
# We now have the ability to visualise the filters that Convolutional Neural Networks (CNNs) learn from their training for
# Computer Vision tasks, and the feature maps that the CNN produces when applied to an image.

# %% [markdown]
# Visualise the filters and feature maps of a CNN trained for image classification using Keras

# %% [markdown]
# ### Pick a model to visualize

# %% [markdown]
# The easiest way to do this in Keras is to select a pre-trained image classification model. Keras lots of these top-performing
# models, All of them were trained on the ImageNet dataset with over a million images.Pick out the VGG16 Model.

# %% [markdown]
# When we import the model from keras.applications, Keras will automatically download the weights in the appropriate directory.
# We then load the model and print out a summary of its structure.

# %%
from keras.applications.vgg16 import VGG16
#Load the model

model=VGG16()
# Out:
# Using TensorFlow backend.

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Visualizing Filters

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
layer_dict=dict([(layer.name,layer) for layer in model.layers])

# %%
layer_dict
# Out:
# {'input_1': <keras.engine.input_layer.InputLayer at 0x143c2fedd08>,
#  'block1_conv1': <keras.layers.convolutional.Conv2D at 0x143dd0ac548>,
#  'block1_conv2': <keras.layers.convolutional.Conv2D at 0x143dd0acc08>,
#  'block1_pool': <keras.layers.pooling.MaxPooling2D at 0x143dd0cad88>,
#  'block2_conv1': <keras.layers.convolutional.Conv2D at 0x143dd0eb408>,
#  'block2_conv2': <keras.layers.convolutional.Conv2D at 0x143dd2fab88>,
#  'block2_pool': <keras.layers.pooling.MaxPooling2D at 0x143dd2fdf88>,
#  'block3_conv1': <keras.layers.convolutional.Conv2D at 0x143dd300988>,
#  'block3_conv2': <keras.layers.convolutional.Conv2D at 0x143dd307548>,
#  'block3_conv3': <keras.layers.convolutional.Conv2D at 0x143dd30a548>,
#  'block3_pool': <keras.layers.pooling.MaxPooling2D at 0x143dd30dfc8>,
#  'block4_conv1': <keras.layers.convolutional.Conv2D at 0x143dd310bc8>,
#  'block4_conv2': <keras.layers.convolutional.Conv2D at 0x143dd317788>,
#  'block4_conv3': <keras.layers.convolutional.Conv2D at 0x143dd319b88>,
#  'block4_pool': <keras.layers.pooling.MaxPooling2D at 0x143dd31be48>,
#  'block5_conv1': <keras.layers.convolutional.Conv2D at 0x143dd31fe48>,
#  'block5_conv2': <keras.layers.convolutional.Conv2D at 0x143dd326a08>,
#  'block5_conv3': <keras.layers.convolutional.Conv2D at 0x143dd329e08>,
#  'block5_pool': <keras.layers.pooling.MaxPooling2D at 0x143dd32e708>,
#  'flatten': <keras.layers.core.Flatten at 0x143dd333988>,
#  'fc1': <keras.layers.core.Dense at 0x143dd333e48>,
#  'fc2': <keras.layers.core.Dense at 0x143dd339e88>,
#  'predictions': <keras.layers.core.Dense at 0x143dd343a88>}

# %%
layer_dict['block5_conv1']

# %%
layer_name='block5_conv1'
filter_index=0 # Which filter in this block we like to visualize
#grab the filters and bias for that layer
filters,bias = layer_dict[layer_name].get_weights()

# %%
type(filters)
# Out:
# numpy.ndarray

# %%
#Normalize the filters to range 0 and 1 so we can visualize them
f_min,f_max=np.amin(filters),np.amax(filters)

# %%
f_min
# Out:
# -0.113298565

# %%
f_max
# Out:
# 0.1904444

# %%
filters = (filters-f_min)/(f_max-f_min)

# %%
filters
# Out:
# array([[[[0.37101   , 0.37769344, 0.39714557, ..., 0.3816266 ,
#           0.37443548, 0.36331734],
#          [0.35700595, 0.37462375, 0.36888897, ..., 0.37681392,
#           0.37259048, 0.32054812],
#          [0.40004942, 0.3976892 , 0.38763985, ..., 0.3381987 ,
#           0.3275626 , 0.366414  ],
#          ...,
#          [0.3796698 , 0.35378772, 0.36516398, ..., 0.37735143,
#           0.3443916 , 0.37030327],
#          [0.39915323, 0.34664136, 0.37555456, ..., 0.40297222,
#           0.37527433, 0.34053624],
#          [0.39707264, 0.3691865 , 0.39002463, ..., 0.36706668,
#           0.3727542 , 0.38478735]],
#
#         [[0.36798766, 0.3626128 , 0.38801128, ..., 0.34613183,
#           0.3461759 , 0.35380656],
#          [0.36899287, 0.35507107, 0.3450437 , ..., 0.37742555,
#           0.368437  , 0.31800282],
#          [0.36325127, 0.39584613, 0.3914547 , ..., 0.31122038,
#           0.35859072, 0.3469171 ],
#          ...,
#          [0.37075377, 0.36369056, 0.37724566, ..., 0.43437505,
#           0.32374972, 0.36858878],
#          [0.32231608, 0.36965016, 0.4085192 , ..., 0.40629956,
#           0.35001093, 0.3516883 ],
#          [0.40830237, 0.3623797 , 0.37267244, ..., 0.35732988,
#           0.4063281 , 0.3901695 ]],
#
#         [[0.38841668, 0.36792544, 0.40556726, ..., 0.36472782,
#           0.36145365, 0.35455012],
#          [0.40789574, 0.33993903, 0.37895486, ..., 0.36338702,
#           0.37567464, 0.30609804],
#          [0.36721116, 0.3805861 , 0.36783704, ..., 0.33381438,
#           0.3543657 , 0.36411107],
#          ...,
#          [0.34355447, 0.3482031 , 0.37544563, ..., 0.41339764,
#           0.32955503, 0.37290263],
#          [0.24406707, 0.34804597, 0.37758684, ..., 0.3511202 ,
#           0.3376719 , 0.3401435 ],
#          [0.39550295, 0.36629418, 0.3890793 , ..., 0.36556944,
#           0.3775655 , 0.39706665]]],
#
#
#        [[[0.38743636, 0.34516957, 0.3732088 , ..., 0.36783215,
#           0.3523169 , 0.35300836],
#          [0.30937442, 0.38855824, 0.39084715, ..., 0.370604  ,
#           0.39092442, 0.3272031 ],
#          [0.39119095, 0.38831097, 0.3474008 , ..., 0.37391523,
#           0.3300419 , 0.359982  ],
#          ...,
#          [0.3740675 , 0.3615229 , 0.33720604, ..., 0.40022764,
#           0.3362065 , 0.3979352 ],
#          [0.38638005, 0.34916583, 0.3684959 , ..., 0.4083925 ,
#           0.3705473 , 0.3345812 ],
#          [0.37696892, 0.3754635 , 0.38460365, ..., 0.3724169 ,
#           0.38259524, 0.39364827]],
#
#         [[0.37130553, 0.3272326 , 0.36425194, ..., 0.34579238,
#           0.30839288, 0.34854996],
#          [0.3530046 , 0.36981836, 0.39288163, ..., 0.34216213,
#           0.38739258, 0.32810473],
#          [0.3432068 , 0.40487105, 0.4016291 , ..., 0.4029838 ,
#           0.3409332 , 0.3478998 ],
#          ...,
#          [0.36039492, 0.37535772, 0.33444166, ..., 0.4285133 ,
#           0.31919718, 0.4155127 ],
#          [0.40333924, 0.3679589 , 0.39043227, ..., 0.38319138,
#           0.34064624, 0.37124264],
#          [0.38602075, 0.37609252, 0.3852975 , ..., 0.35457826,
#           0.40915787, 0.41284734]],
#
#         [[0.36716738, 0.33461186, 0.37831277, ..., 0.37343478,
#           0.33463755, 0.35493588],
#          [0.4234908 , 0.3502753 , 0.40592608, ..., 0.33249754,
#           0.3783973 , 0.31084663],
#          [0.37237388, 0.38223863, 0.36724886, ..., 0.45905992,
#           0.3420676 , 0.35798913],
#          ...,
#          [0.35179973, 0.36390767, 0.34418342, ..., 0.40872505,
#           0.3313145 , 0.40984324],
#          [0.32370147, 0.3464065 , 0.37687746, ..., 0.32621714,
#           0.32498354, 0.37119368],
#          [0.38935462, 0.37948   , 0.38753757, ..., 0.36234364,
#           0.38385972, 0.4061926 ]]],
#
#
#        [[[0.33740675, 0.36902115, 0.3864207 , ..., 0.36062598,
#           0.3453382 , 0.35947642],
#          [0.31982148, 0.3740959 , 0.38232997, ..., 0.38578182,
#           0.40883544, 0.33293194],
#          [0.41896588, 0.3865951 , 0.35447174, ..., 0.4019004 ,
#           0.36232832, 0.36170053],
#          ...,
#          [0.40320072, 0.35231316, 0.33149597, ..., 0.3785975 ,
#           0.34130695, 0.373179  ],
#          [0.3409097 , 0.3659364 , 0.30874044, ..., 0.36987358,
#           0.39382267, 0.3140847 ],
#          [0.38596404, 0.3887269 , 0.3798586 , ..., 0.4051225 ,
#           0.33026645, 0.38843665]],
#
#         [[0.35222068, 0.36642146, 0.37168053, ..., 0.39612648,
#           0.3296775 , 0.34912395],
#          [0.3494729 , 0.37548846, 0.37757346, ..., 0.35035378,
#           0.38937262, 0.3311406 ],
#          [0.36829555, 0.3978967 , 0.3638648 , ..., 0.4830192 ,
#           0.3598739 , 0.3501079 ],
#          ...,
#          [0.38691399, 0.35715854, 0.33947405, ..., 0.37074015,
#           0.3187519 , 0.37243113],
#          [0.35169864, 0.36085135, 0.3435859 , ..., 0.35439944,
#           0.37037402, 0.33995643],
#          [0.39210194, 0.38539305, 0.37830973, ..., 0.37123835,
#           0.31424224, 0.3898711 ]],
#
#         [[0.37521806, 0.36234406, 0.37560105, ..., 0.39681017,
#           0.35568655, 0.35891676],
#          [0.39098918, 0.36699468, 0.39949122, ..., 0.37119415,
#           0.3688782 , 0.31643736],
#          [0.3745611 , 0.39480388, 0.35532176, ..., 0.5073731 ,
#           0.36110568, 0.3560503 ],
#          ...,
#          [0.36923864, 0.35172504, 0.3317977 , ..., 0.35114285,
#           0.33742148, 0.3641344 ],
#          [0.3243934 , 0.35356605, 0.37008432, ..., 0.33790207,
#           0.35440898, 0.35680524],
#          [0.38718903, 0.38458297, 0.37455556, ..., 0.37221783,
#           0.3179642 , 0.38897017]]]], dtype=float32)

# %%
#Plot first few filters
n_filters,index = 6,1
for i in range(n_filters):
    f = filters[:,:,:,i]
    #Plot each channel
    for j in range(3):
        ax=plt.subplot(n_filters,3,index)
        ax.set_xticks([])
        ax.set_yticks([])
        
        plt.imshow(f[:,:,j],cmap='viridis')# yellow represents 1 dark blue represents 0
        index += 1
plt.show()

# %% [markdown]
# ### Visualizing Feature Maps

# %% [markdown]
# The reason for visualising a feature map for a specific input image is to try to gain some understanding of
# what features our CNN detects. It is also interesting to directly observe a common idea in Deep Learning, that the early layers of the network detect low-level features (colours, edges, etc) and the later layers of the network detect high-level features (shapes and objects).

# %%
from keras.preprocessing.image import load_img,img_to_array
from keras.models import Model
from keras.applications.vgg16 import VGG16,preprocess_input

# %%
model.inputs
# Out:
# [<tf.Tensor 'input_1:0' shape=(None, 224, 224, 3) dtype=float32>]

# %%
layer_name='block1_conv2'
model=Model(inputs=model.inputs,outputs=layer_dict[layer_name].output)

# %%
#Prepare the image
image=load_img('San06-11-20.jpg',target_size=(224,224))
image=img_to_array(image)
image=np.expand_dims(image,axis=0)
image=preprocess_input(image)

# %%
#Apply the model to image
feature_maps=model.predict(image)

# %%
# np.set_printoptions(linewidth=200)
square=8
index=1

for _ in range(square):
    for _ in range(square):
        ax=plt.subplot(square,square,index)
        ax.set_xticks([])
        ax.set_yticks([])
        
        plt.imshow(feature_maps[0,:,:,index-1],cmap='viridis')
        index +=1
plt.show()

# %%
layer_name='block3_conv2'
model=Model(inputs=model.inputs,outputs=layer_dict[layer_name].output)
#Apply the model to image
feature_maps=model.predict(image)

# np.set_printoptions(linewidth=200)
square=8
index=1

for _ in range(square):
    for _ in range(square):
        ax=plt.subplot(square,square,index)
        ax.set_xticks([])
        ax.set_yticks([])
        
        plt.imshow(feature_maps[0,:,:,index-1],cmap='viridis')
        index +=1
plt.show()

# %%
from keras.applications.vgg16 import decode_predictions

# %%
# load an image from file
image = load_img('Cat.jpg', target_size=(224, 224))
# convert the image pixels to a numpy array
image = img_to_array(image)
# reshape data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
# prepare the image for the VGG model
image = preprocess_input(image)
# load the model
model = VGG16()
# predict the probability across all output classes
yhat = model.predict(image)
# convert the probabilities to class labels
label = decode_predictions(yhat,top=1000)
# retrieve the most likely result, e.g. highest probability
label = label[0][0]
# print the classification
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# weasel (35.00%)

# %%
label
# Out:
# ('n02441942', 'weasel', 0.35001808)

# %%
decode_predictions(yhat,top=1000)[0]
# Out:
# [('n02441942', 'weasel', 0.35001808),
#  ('n02443484', 'black-footed_ferret', 0.22704609),
#  ('n02443114', 'polecat', 0.14525808),
#  ('n02098286', 'West_Highland_white_terrier', 0.06715913),
#  ('n02120079', 'Arctic_fox', 0.037061214),
#  ('n02111889', 'Samoyed', 0.025108412),
#  ('n01877812', 'wallaby', 0.020600053),
#  ('n02442845', 'mink', 0.016358951),
#  ('n02123597', 'Siamese_cat', 0.0078073493),
#  ('n02111500', 'Great_Pyrenees', 0.00592491),
#  ('n02109961', 'Eskimo_dog', 0.005805366),
#  ('n02108915', 'French_bulldog', 0.005380283),
#  ('n02110185', 'Siberian_husky', 0.0053727636),
#  ('n02114548', 'white_wolf', 0.0033498162),
#  ('n01883070', 'wombat', 0.0032805307),
#  ('n01819313', 'sulphur-crested_cockatoo', 0.0031060907),
#  ('n02104029', 'kuvasz', 0.0029950396),
#  ('n02361337', 'marmot', 0.0027225544),
#  ('n02346627', 'porcupine', 0.002714574),
#  ('n03223299', 'doormat', 0.0026784528),
#  ('n02134084', 'ice_bear', 0.0024561994),
#  ('n02445715', 'skunk', 0.0023870182),
#  ('n01514859', 'hen', 0.0018570307),
#  ('n02342885', 'hamster', 0.0017014197),
#  ('n02100735', 'English_setter', 0.0016135516),
#  ('n02112018', 'Pomeranian', 0.0014605346),
#  ('n02325366', 'wood_rabbit', 0.0013739982),
#  ('n02095314', 'wire-haired_fox_terrier', 0.0013607398),
#  ('n02085620', 'Chihuahua', 0.0013543506),
#  ('n02113624', 'toy_poodle', 0.0012872461),
#  ('n02137549', 'mongoose', 0.0011648646),
#  ('n02090622', 'borzoi', 0.0011009113),
#  ('n02095889', 'Sealyham_terrier', 0.0010686112),
#  ('n02363005', 'beaver', 0.0009700792),
#  ('n02326432', 'hare', 0.0009055245),
#  ('n02085936', 'Maltese_dog', 0.0008874178),
#  ('n01872401', 'echidna', 0.00087269914),
#  ('n02098105', 'soft-coated_wheaten_terrier', 0.00086632493),
#  ('n02113712', 'miniature_poodle', 0.000863296),
#  ('n01494475', 'hammerhead', 0.00082492986),
#  ('n02447366', 'badger', 0.0008111992),
#  ('n02087046', 'toy_terrier', 0.000774075),
#  ('n02110063', 'malamute', 0.00076312496),
#  ('n02101388', 'Brittany_spaniel', 0.00075707183),
#  ('n01855672', 'goose', 0.00074460596),
#  ('n02113023', 'Pembroke', 0.0007343122),
#  ('n02086910', 'papillon', 0.0007040761),
#  ('n02086240', 'Shih-Tzu', 0.00067605026),
#  ('n02102040', 'English_springer', 0.0006283029),
#  ('n03958227', 'plastic_bag', 0.0006200799),
#  ('n02909870', 'bucket', 0.0005782829),
#  ('n02098413', 'Lhasa', 0.0005711932),
#  ('n02127052', 'lynx', 0.0005683692),
#  ('n02364673', 'guinea_pig', 0.00055877597),
#  ('n02747177', 'ashcan', 0.00054815435),
#  ('n02094114', 'Norfolk_terrier', 0.00053884037),
#  ('n02096177', 'cairn', 0.0005322385),
#  ('n02097298', 'Scotch_terrier', 0.00052259007),
#  ('n02124075', 'Egyptian_cat', 0.00051718956),
#  ('n02328150', 'Angora', 0.00050768175),
#  ('n02101556', 'clumber', 0.000479436),
#  ('n02086079', 'Pekinese', 0.00042422078),
#  ('n02105641', 'Old_English_sheepdog', 0.00040693456),
#  ('n02091467', 'Norwegian_elkhound', 0.00038738904),
#  ('n02110958', 'pug', 0.00037824616),
#  ('n02487347', 'macaque', 0.00036221047),
#  ('n02099712', 'Labrador_retriever', 0.0003574611),
#  ('n02099601', 'golden_retriever', 0.00035388183),
#  ('n02123045', 'tabby', 0.0003429631),
#  ('n02115641', 'dingo', 0.00033807222),
#  ('n02444819', 'otter', 0.00033556676),
#  ('n02113186', 'Cardigan', 0.00033287343),
#  ('n02093647', 'Bedlington_terrier', 0.00031779322),
#  ('n02123394', 'Persian_cat', 0.0003139246),
#  ('n01796340', 'ptarmigan', 0.00029708067),
#  ('n02138441', 'meerkat', 0.00029310284),
#  ('n03794056', 'mousetrap', 0.0002862914),
#  ('n02094258', 'Norwich_terrier', 0.0002804823),
#  ('n02106030', 'collie', 0.0002784263),
#  ('n02395406', 'hog', 0.0002746562),
#  ('n03887697', 'paper_towel', 0.00027215428),
#  ('n02105505', 'komondor', 0.0002706118),
#  ('n02102177', 'Welsh_springer_spaniel', 0.00026454736),
#  ('n01943899', 'conch', 0.00025857973),
#  ('n02106166', 'Border_collie', 0.00025738907),
#  ('n02097047', 'miniature_schnauzer', 0.00025421396),
#  ('n02119789', 'kit_fox', 0.0002487293),
#  ('n02536864', 'coho', 0.0002440626),
#  ('n02110341', 'dalmatian', 0.00021221601),
#  ('n02356798', 'fox_squirrel', 0.00021210097),
#  ('n01873310', 'platypus', 0.00019709811),
#  ('n02097658', 'silky_terrier', 0.00019544121),
#  ('n01632777', 'axolotl', 0.00019355261),
#  ('n02104365', 'schipperke', 0.0001874778),
#  ('n02120505', 'grey_fox', 0.00017075517),
#  ('n03930313', 'picket_fence', 0.00016905981),
#  ('n02108089', 'boxer', 0.00015983045),
#  ('n02095570', 'Lakeland_terrier', 0.00015844197),
#  ('n02093256', 'Staffordshire_bullterrier', 0.00015281848),
#  ('n02088364', 'beagle', 0.0001504293),
#  ('n04409515', 'tennis_ball', 0.00015013128),
#  ('n02091032', 'Italian_greyhound', 0.00014817552),
#  ('n02109525', 'Saint_Bernard', 0.00014806562),
#  ('n02091244', 'Ibizan_hound', 0.00014435168),
#  ('n02077923', 'sea_lion', 0.00014265905),
#  ('n02093428', 'American_Staffordshire_terrier', 0.00013552298),
#  ('n04376876', 'syringe', 0.00013159424),
#  ('n02096585', 'Boston_bull', 0.00012954709),
#  ('n02321529', 'sea_cucumber', 0.00012840852),
#  ('n09421951', 'sandbar', 0.00012755938),
#  ('n02106662', 'German_shepherd', 0.00012454999),
#  ('n02119022', 'red_fox', 0.00012248088),
#  ('n02113799', 'standard_poodle', 0.000119721175),
#  ('n04265275', 'space_heater', 0.000119244076),
#  ('n02454379', 'armadillo', 0.00011471353),
#  ('n01945685', 'slug', 0.00011447835),
#  ('n02112137', 'chow', 0.00011140175),
#  ('n02086646', 'Blenheim_spaniel', 0.0001089471),
#  ('n02457408', 'three-toed_sloth', 0.0001066492),
#  ('n02105412', 'kelpie', 0.00010651239),
#  ('n02490219', 'marmoset', 0.00010188636),
#  ('n02509815', 'lesser_panda', 0.000100179524),
#  ('n02437616', 'llama', 9.9988916e-05),
#  ('n02110806', 'basenji', 9.820994e-05),
#  ('n02105855', 'Shetland_sheepdog', 9.555077e-05),
#  ('n04254777', 'sock', 9.4929324e-05),
#  ('n01695060', 'Komodo_dragon', 9.3497874e-05),
#  ('n01514668', 'cock', 8.962914e-05),
#  ('n02510455', 'giant_panda', 8.940726e-05),
#  ('n04208210', 'shovel', 8.823402e-05),
#  ('n02099849', 'Chesapeake_Bay_retriever', 8.7277775e-05),
#  ('n01806143', 'peacock', 8.578498e-05),
#  ('n01693334', 'green_lizard', 8.289981e-05),
#  ('n02091134', 'whippet', 7.85215e-05),
#  ('n02906734', 'broom', 7.4739335e-05),
#  ('n03141823', 'crutch', 7.431552e-05),
#  ('n02123159', 'tiger_cat', 7.2735784e-05),
#  ('n01496331', 'electric_ray', 7.237328e-05),
#  ('n02526121', 'eel', 7.054932e-05),
#  ('n01882714', 'koala', 7.003222e-05),
#  ('n02497673', 'Madagascar_cat', 6.798555e-05),
#  ('n02894605', 'breakwater', 6.778589e-05),
#  ('n02093991', 'Irish_terrier', 6.7744986e-05),
#  ('n09428293', 'seashore', 6.770268e-05),
#  ('n02089867', 'Walker_hound', 6.3346175e-05),
#  ('n02114367', 'timber_wolf', 6.225404e-05),
#  ('n02114855', 'coyote', 6.2214924e-05),
#  ('n02102318', 'cocker_spaniel', 6.129051e-05),
#  ('n15075141', 'toilet_tissue', 6.1157916e-05),
#  ('n02093754', 'Border_terrier', 5.922125e-05),
#  ('n03498962', 'hatchet', 5.9039445e-05),
#  ('n03717622', 'manhole_cover', 5.4944132e-05),
#  ('n02112350', 'keeshond', 5.4682394e-05),
#  ('n03891251', 'park_bench', 5.2892035e-05),
#  ('n03733281', 'maze', 5.2526695e-05),
#  ('n02786058', 'Band_Aid', 5.174426e-05),
#  ('n02074367', 'dugong', 5.0576902e-05),
#  ('n09332890', 'lakeside', 4.8666847e-05),
#  ('n02090721', 'Irish_wolfhound', 4.7456946e-05),
#  ('n02492035', 'capuchin', 4.7150414e-05),
#  ('n02655020', 'puffer', 4.5501525e-05),
#  ('n01498041', 'stingray', 4.5490156e-05),
#  ('n01616318', 'vulture', 4.3880667e-05),
#  ('n03445777', 'golf_ball', 4.3390457e-05),
#  ('n02808304', 'bath_towel', 4.264981e-05),
#  ('n04040759', 'radiator', 4.1710373e-05),
#  ('n02640242', 'sturgeon', 4.1630454e-05),
#  ('n02494079', 'squirrel_monkey', 4.1432297e-05),
#  ('n02096294', 'Australian_terrier', 4.095194e-05),
#  ('n03481172', 'hammer', 4.0621628e-05),
#  ('n02096051', 'Airedale', 4.0022675e-05),
#  ('n02107142', 'Doberman', 3.985877e-05),
#  ('n07714990', 'broccoli', 3.8848502e-05),
#  ('n04399382', 'teddy', 3.858543e-05),
#  ('n04235860', 'sleeping_bag', 3.812902e-05),
#  ('n04482393', 'tricycle', 3.692868e-05),
#  ('n02096437', 'Dandie_Dinmont', 3.5563447e-05),
#  ('n02493509', 'titi', 3.4881905e-05),
#  ('n02085782', 'Japanese_spaniel', 3.3932873e-05),
#  ('n04049303', 'rain_barrel', 3.26426e-05),
#  ('n04589890', 'window_screen', 3.2509233e-05),
#  ('n02105251', 'briard', 3.2424457e-05),
#  ('n02111277', 'Newfoundland', 3.2408905e-05),
#  ('n04493381', 'tub', 3.23031e-05),
#  ('n03803284', 'muzzle', 3.185039e-05),
#  ('n02009912', 'American_egret', 3.1224317e-05),
#  ('n10148035', 'groom', 3.0734394e-05),
#  ('n02091831', 'Saluki', 3.070255e-05),
#  ('n02105056', 'groenendael', 3.0517123e-05),
#  ('n04371774', 'swing', 2.9778002e-05),
#  ('n04435653', 'tile_roof', 2.9444105e-05),
#  ('n01677366', 'common_iguana', 2.9267701e-05),
#  ('n04033901', 'quill', 2.9065262e-05),
#  ('n02823428', 'beer_bottle', 2.8877355e-05),
#  ('n03970156', 'plunger', 2.8723382e-05),
#  ('n02317335', 'starfish', 2.8543704e-05),
#  ('n02107683', 'Bernese_mountain_dog', 2.8373317e-05),
#  ('n02012849', 'crane', 2.815066e-05),
#  ('n02132136', 'brown_bear', 2.7367925e-05),
#  ('n01665541', 'leatherback_turtle', 2.734366e-05),
#  ('n03976657', 'pole', 2.686255e-05),
#  ('n02100877', 'Irish_setter', 2.6303616e-05),
#  ('n01689811', 'alligator_lizard', 2.6102207e-05),
#  ('n02788148', 'bannister', 2.5814717e-05),
#  ('n02094433', 'Yorkshire_terrier', 2.5331114e-05),
#  ('n01751748', 'sea_snake', 2.5315852e-05),
#  ('n03026506', 'Christmas_stocking', 2.4891488e-05),
#  ('n02100236', 'German_short-haired_pointer', 2.4795889e-05),
#  ('n01484850', 'great_white_shark', 2.4785177e-05),
#  ('n04557648', 'water_bottle', 2.4464227e-05),
#  ('n02500267', 'indri', 2.4306346e-05),
#  ('n02088094', 'Afghan_hound', 2.4141837e-05),
#  ('n04254680', 'soccer_ball', 2.4086943e-05),
#  ('n01440764', 'tench', 2.3959972e-05),
#  ('n01806567', 'quail', 2.3398958e-05),
#  ('n04604644', 'worm_fence', 2.3244094e-05),
#  ('n04152593', 'screen', 2.3166309e-05),
#  ('n01692333', 'Gila_monster', 2.3091312e-05),
#  ('n02971356', 'carton', 2.3000543e-05),
#  ('n02860847', 'bobsled', 2.2743052e-05),
#  ('n02219486', 'ant', 2.2721653e-05),
#  ('n02112706', 'Brabancon_griffon', 2.2522847e-05),
#  ('n02105162', 'malinois', 2.2212438e-05),
#  ('n03649909', 'lawn_mower', 2.1581287e-05),
#  ('n02125311', 'cougar', 2.1418753e-05),
#  ('n02092339', 'Weimaraner', 2.0866037e-05),
#  ('n01924916', 'flatworm', 2.0696925e-05),
#  ('n04239074', 'sliding_door', 2.055808e-05),
#  ('n02412080', 'ram', 1.9945746e-05),
#  ('n01675722', 'banded_gecko', 1.9837296e-05),
#  ('n04507155', 'umbrella', 1.975926e-05),
#  ('n04404412', 'television', 1.9699746e-05),
#  ('n02097209', 'standard_schnauzer', 1.9669447e-05),
#  ('n04367480', 'swab', 1.9420613e-05),
#  ('n01728572', 'thunder_snake', 1.9005032e-05),
#  ('n04509417', 'unicycle', 1.8678082e-05),
#  ('n02093859', 'Kerry_blue_terrier', 1.8617919e-05),
#  ('n04517823', 'vacuum', 1.8598237e-05),
#  ('n02128757', 'snow_leopard', 1.8508283e-05),
#  ('n07860988', 'dough', 1.8272307e-05),
#  ('n02396427', 'wild_boar', 1.8195724e-05),
#  ('n04326547', 'stone_wall', 1.819359e-05),
#  ('n02051845', 'pelican', 1.7950257e-05),
#  ('n03944341', 'pinwheel', 1.762741e-05),
#  ('n02107312', 'miniature_pinscher', 1.7621005e-05),
#  ('n03891332', 'parking_meter', 1.751826e-05),
#  ('n01740131', 'night_snake', 1.7490549e-05),
#  ('n03825788', 'nipple', 1.7375716e-05),
#  ('n02797295', 'barrow', 1.7309048e-05),
#  ('n01950731', 'sea_slug', 1.7265309e-05),
#  ('n07615774', 'ice_lolly', 1.7162527e-05),
#  ('n02109047', 'Great_Dane', 1.701452e-05),
#  ('n02088238', 'basset', 1.6999955e-05),
#  ('n02107574', 'Greater_Swiss_Mountain_dog', 1.6846021e-05),
#  ('n02133161', 'American_black_bear', 1.6745542e-05),
#  ('n02106382', 'Bouvier_des_Flandres', 1.6607433e-05),
#  ('n02099267', 'flat-coated_retriever', 1.655214e-05),
#  ('n02129604', 'tiger', 1.6163407e-05),
#  ('n03125729', 'cradle', 1.598825e-05),
#  ('n02056570', 'king_penguin', 1.594817e-05),
#  ('n03127925', 'crate', 1.5461344e-05),
#  ('n02877765', 'bottlecap', 1.5277192e-05),
#  ('n01748264', 'Indian_cobra', 1.5174258e-05),
#  ('n02493793', 'spider_monkey', 1.4910991e-05),
#  ('n01833805', 'hummingbird', 1.4717272e-05),
#  ('n03457902', 'greenhouse', 1.4662258e-05),
#  ('n03642806', 'laptop', 1.45922995e-05),
#  ('n12144580', 'corn', 1.4539043e-05),
#  ('n02514041', 'barracouta', 1.4472434e-05),
#  ('n06794110', 'street_sign', 1.4335986e-05),
#  ('n03207941', 'dishwasher', 1.4190914e-05),
#  ('n04004767', 'printer', 1.4135455e-05),
#  ('n13133613', 'ear', 1.4010184e-05),
#  ('n01944390', 'snail', 1.4008155e-05),
#  ('n01749939', 'green_mamba', 1.37558e-05),
#  ('n02097130', 'giant_schnauzer', 1.3434484e-05),
#  ('n01847000', 'drake', 1.336805e-05),
#  ('n02102973', 'Irish_water_spaniel', 1.3309814e-05),
#  ('n03773504', 'missile', 1.3231121e-05),
#  ('n11939491', 'daisy', 1.3001615e-05),
#  ('n02006656', 'spoonbill', 1.2910726e-05),
#  ('n03786901', 'mortar', 1.2841004e-05),
#  ('n03991062', 'pot', 1.2819615e-05),
#  ('n01797886', 'ruffed_grouse', 1.27100675e-05),
#  ('n02117135', 'hyena', 1.262927e-05),
#  ('n01669191', 'box_turtle', 1.24749695e-05),
#  ('n07716358', 'zucchini', 1.2404537e-05),
#  ('n03743016', 'megalith', 1.2354821e-05),
#  ('n04599235', 'wool', 1.2351428e-05),
#  ('n02808440', 'bathtub', 1.211766e-05),
#  ('n02892201', 'brass', 1.2117267e-05),
#  ('n02799071', 'baseball', 1.2025815e-05),
#  ('n03764736', 'milk_can', 1.1963928e-05),
#  ('n02486261', 'patas', 1.1905664e-05),
#  ('n02974003', 'car_wheel', 1.1789727e-05),
#  ('n01817953', 'African_grey', 1.1584263e-05),
#  ('n04344873', 'studio_couch', 1.1566392e-05),
#  ('n03404251', 'fur_coat', 1.1473471e-05),
#  ('n02102480', 'Sussex_spaniel', 1.14529075e-05),
#  ('n01491361', 'tiger_shark', 1.1384107e-05),
#  ('n01807496', 'partridge', 1.1316983e-05),
#  ('n01685808', 'whiptail', 1.1297443e-05),
#  ('n03630383', 'lab_coat', 1.1276615e-05),
#  ('n01664065', 'loggerhead', 1.11234385e-05),
#  ('n03376595', 'folding_chair', 1.1112528e-05),
#  ('n03000134', 'chainlink_fence', 1.106436e-05),
#  ('n04008634', 'projectile', 1.1039507e-05),
#  ('n03710193', 'mailbox', 1.0991686e-05),
#  ('n04154565', 'screwdriver', 1.0976875e-05),
#  ('n04141327', 'scabbard', 1.0893343e-05),
#  ('n02058221', 'albatross', 1.0877273e-05),
#  ('n03782006', 'monitor', 1.0686396e-05),
#  ('n02089973', 'English_foxhound', 1.064975e-05),
#  ('n03876231', 'paintbrush', 1.0612278e-05),
#  ('n04447861', 'toilet_seat', 1.0594521e-05),
#  ('n01582220', 'magpie', 1.0516114e-05),
#  ('n02097474', 'Tibetan_terrier', 1.040548e-05),
#  ('n03775071', 'mitten', 1.0349711e-05),
#  ('n04204347', 'shopping_cart', 1.0332482e-05),
#  ('n01667778', 'terrapin', 1.0102384e-05),
#  ('n03690938', 'lotion', 1.0029964e-05),
#  ('n04336792', 'stretcher', 1.0026139e-05),
#  ('n03899768', 'patio', 9.952736e-06),
#  ('n02107908', 'Appenzeller', 9.504587e-06),
#  ('n02088632', 'bluetick', 9.434795e-06),
#  ('n04560804', 'water_jug', 9.428436e-06),
#  ('n03871628', 'packet', 9.368098e-06),
#  ('n04067472', 'reel', 9.344978e-06),
#  ('n02814860', 'beacon', 9.231483e-06),
#  ('n03085013', 'computer_keyboard', 9.115349e-06),
#  ('n01534433', 'junco', 9.072126e-06),
#  ('n04606251', 'wreck', 8.84262e-06),
#  ('n01986214', 'hermit_crab', 8.827101e-06),
#  ('n01784675', 'centipede', 8.81856e-06),
#  ('n03014705', 'chest', 8.7564695e-06),
#  ('n02319095', 'sea_urchin', 8.596461e-06),
#  ('n09399592', 'promontory', 8.594281e-06),
#  ('n01729322', 'hognose_snake', 8.580817e-06),
#  ('n03134739', 'croquet_ball', 8.461402e-06),
#  ('n01729977', 'green_snake', 8.441663e-06),
#  ('n03188531', 'diaper', 8.377456e-06),
#  ('n02692877', 'airship', 8.366238e-06),
#  ('n02777292', 'balance_beam', 8.237734e-06),
#  ('n03355925', 'flagpole', 8.184508e-06),
#  ('n03535780', 'horizontal_bar', 7.96632e-06),
#  ('n02280649', 'cabbage_butterfly', 7.872962e-06),
#  ('n12985857', 'coral_fungus', 7.815315e-06),
#  ('n03627232', 'knot', 7.713251e-06),
#  ('n02092002', 'Scottish_deerhound', 7.6777305e-06),
#  ('n01682714', 'American_chameleon', 7.6188903e-06),
#  ('n02483362', 'gibbon', 7.583588e-06),
#  ('n02977058', 'cash_machine', 7.576691e-06),
#  ('n03942813', 'ping-pong_ball', 7.4896484e-06),
#  ('n02113978', 'Mexican_hairless', 7.424074e-06),
#  ('n03291819', 'envelope', 7.4025324e-06),
#  ('n02115913', 'dhole', 7.399632e-06),
#  ('n04116512', 'rubber_eraser', 7.2525872e-06),
#  ('n01580077', 'jay', 7.156944e-06),
#  ('n02231487', 'walking_stick', 7.153669e-06),
#  ('n02486410', 'baboon', 7.1389136e-06),
#  ('n02641379', 'gar', 7.0432316e-06),
#  ('n04118776', 'rule', 6.963659e-06),
#  ('n03594734', 'jean', 6.91955e-06),
#  ('n03937543', 'pill_bottle', 6.8515465e-06),
#  ('n09288635', 'geyser', 6.7441465e-06),
#  ('n01687978', 'agama', 6.72166e-06),
#  ('n02484975', 'guenon', 6.697026e-06),
#  ('n07714571', 'head_cabbage', 6.667679e-06),
#  ('n03770679', 'minivan', 6.660059e-06),
#  ('n03250847', 'drumstick', 6.622861e-06),
#  ('n03047690', 'clog', 6.6140997e-06),
#  ('n01776313', 'tick', 6.54343e-06),
#  ('n02037110', 'oystercatcher', 6.440823e-06),
#  ('n02108000', 'EntleBucher', 6.3208554e-06),
#  ('n03933933', 'pier', 6.2770455e-06),
#  ('n02795169', 'barrel', 6.270524e-06),
#  ('n03666591', 'lighter', 6.2507615e-06),
#  ('n01755581', 'diamondback', 6.244094e-06),
#  ('n04553703', 'washbasin', 6.1692954e-06),
#  ('n03041632', 'cleaver', 6.1271726e-06),
#  ('n03255030', 'dumbbell', 6.0754505e-06),
#  ('n03485794', 'handkerchief', 6.059313e-06),
#  ('n04270147', 'spatula', 5.985779e-06),
#  ('n03623198', 'knee_pad', 5.9326867e-06),
#  ('n03482405', 'hamper', 5.928977e-06),
#  ('n03995372', 'power_drill', 5.8126257e-06),
#  ('n01753488', 'horned_viper', 5.7979596e-06),
#  ('n03832673', 'notebook', 5.7927423e-06),
#  ('n02727426', 'apiary', 5.7429456e-06),
#  ('n02883205', 'bow_tie', 5.7370717e-06),
#  ('n04591713', 'wine_bottle', 5.507221e-06),
#  ('n02106550', 'Rottweiler', 5.5008904e-06),
#  ('n03000684', 'chain_saw', 5.4402676e-06),
#  ('n03938244', 'pillow', 5.3774306e-06),
#  ('n01756291', 'sidewinder', 5.3123895e-06),
#  ('n03903868', 'pedestal', 5.285959e-06),
#  ('n03207743', 'dishrag', 5.2015366e-06),
#  ('n01737021', 'water_snake', 5.1952106e-06),
#  ('n02951358', 'canoe', 5.1877055e-06),
#  ('n04120489', 'running_shoe', 5.1831307e-06),
#  ('n03998194', 'prayer_rug', 5.139765e-06),
#  ('n04579432', 'whistle', 5.1292036e-06),
#  ('n03065424', 'coil', 5.0621466e-06),
#  ('n01985128', 'crayfish', 5.0375756e-06),
#  ('n02108422', 'bull_mastiff', 5.0295207e-06),
#  ('n02879718', 'bow', 4.9988066e-06),
#  ('n04592741', 'wing', 4.9984396e-06),
#  ('n02114712', 'red_wolf', 4.975217e-06),
#  ('n01601694', 'water_ouzel', 4.9612727e-06),
#  ('n02110627', 'affenpinscher', 4.9532314e-06),
#  ('n04554684', 'washer', 4.9228847e-06),
#  ('n02488291', 'langur', 4.8783922e-06),
#  ('n03670208', 'limousine', 4.8162815e-06),
#  ('n04355338', 'sundial', 4.8025263e-06),
#  ('n03483316', 'hand_blower', 4.751942e-06),
#  ('n09229709', 'bubble', 4.748214e-06),
#  ('n01443537', 'goldfish', 4.680149e-06),
#  ('n01698640', 'American_alligator', 4.678261e-06),
#  ('n13052670', 'hen-of-the-woods', 4.6021446e-06),
#  ('n02233338', 'cockroach', 4.5975166e-06),
#  ('n04033995', 'quilt', 4.582113e-06),
#  ('n02111129', 'Leonberg', 4.559033e-06),
#  ('n04357314', 'sunscreen', 4.546767e-06),
#  ('n13044778', 'earthstar', 4.54619e-06),
#  ('n02488702', 'colobus', 4.5200914e-06),
#  ('n02101006', 'Gordon_setter', 4.4879926e-06),
#  ('n02090379', 'redbone', 4.484364e-06),
#  ('n01914609', 'sea_anemone', 4.424535e-06),
#  ('n03325584', 'feather_boa', 4.421519e-06),
#  ('n04590129', 'window_shade', 4.3477544e-06),
#  ('n03843555', 'oil_filter', 4.2977285e-06),
#  ('n03877472', 'pajama', 4.1864414e-06),
#  ('n02134418', 'sloth_bear', 4.1496655e-06),
#  ('n04099969', 'rocking_chair', 4.1339367e-06),
#  ('n02869837', 'bonnet', 4.122445e-06),
#  ('n04074963', 'remote_control', 4.1041844e-06),
#  ('n03804744', 'nail', 4.0947157e-06),
#  ('n03983396', 'pop_bottle', 4.0706336e-06),
#  ('n09468604', 'valley', 4.0549844e-06),
#  ('n01734418', 'king_snake', 4.044391e-06),
#  ('n04133789', 'sandal', 3.9701463e-06),
#  ('n03532672', 'hook', 3.9318265e-06),
#  ('n04141975', 'scale', 3.854175e-06),
#  ('n09246464', 'cliff', 3.8499284e-06),
#  ('n07718472', 'cucumber', 3.828017e-06),
#  ('n03658185', 'letter_opener', 3.7773407e-06),
#  ('n04118538', 'rugby_ball', 3.7328418e-06),
#  ('n03840681', 'ocarina', 3.7140253e-06),
#  ('n03796401', 'moving_van', 3.69406e-06),
#  ('n13054560', 'bolete', 3.6675995e-06),
#  ('n02930766', 'cab', 3.6058038e-06),
#  ('n03133878', 'Crock_Pot', 3.5140993e-06),
#  ('n02814533', 'beach_wagon', 3.4948084e-06),
#  ('n04131690', 'saltshaker', 3.4575696e-06),
#  ('n07754684', 'jackfruit', 3.446298e-06),
#  ('n04037443', 'racer', 3.4038578e-06),
#  ('n03791053', 'motor_scooter', 3.3775652e-06),
#  ('n02951585', 'can_opener', 3.3768376e-06),
#  ('n01614925', 'bald_eagle', 3.3494982e-06),
#  ('n02108551', 'Tibetan_mastiff', 3.3442889e-06),
#  ('n03680355', 'Loafer', 3.2616636e-06),
#  ('n04228054', 'ski', 3.2595146e-06),
#  ('n01667114', 'mud_turtle', 3.2337512e-06),
#  ('n03787032', 'mortarboard', 3.211828e-06),
#  ('n01744401', 'rock_python', 3.210147e-06),
#  ('n12998815', 'agaric', 3.1978236e-06),
#  ('n13040303', 'stinkhorn', 3.1788838e-06),
#  ('n02687172', 'aircraft_carrier', 3.173392e-06),
#  ('n04350905', 'suit', 3.1682423e-06),
#  ('n03633091', 'ladle', 3.1494865e-06),
#  ('n03450230', 'gown', 3.0971355e-06),
#  ('n03793489', 'mouse', 3.095774e-06),
#  ('n04201297', 'shoji', 3.0636547e-06),
#  ('n07880968', 'burrito', 3.0398685e-06),
#  ('n04070727', 'refrigerator', 3.0388364e-06),
#  ('n03344393', 'fireboat', 3.0156539e-06),
#  ('n01798484', 'prairie_chicken', 2.9954122e-06),
#  ('n09193705', 'alp', 2.9839846e-06),
#  ('n04522168', 'vase', 2.9764615e-06),
#  ('n03160309', 'dam', 2.9303017e-06),
#  ('n02948072', 'candle', 2.906777e-06),
#  ('n03271574', 'electric_fan', 2.9013597e-06),
#  ('n04332243', 'strainer', 2.8747677e-06),
#  ('n02804414', 'bassinet', 2.8733505e-06),
#  ('n04317175', 'stethoscope', 2.8557602e-06),
#  ('n03888605', 'parallel_bars', 2.8468628e-06),
#  ('n02950826', 'cannon', 2.8323666e-06),
#  ('n02172182', 'dung_beetle', 2.8316185e-06),
#  ('n04371430', 'swimming_trunks', 2.8288382e-06),
#  ('n04417672', 'thatch', 2.8212944e-06),
#  ('n04476259', 'tray', 2.8021811e-06),
#  ('n02002556', 'white_stork', 2.7904712e-06),
#  ('n02917067', 'bullet_train', 2.7515878e-06),
#  ('n03127747', 'crash_helmet', 2.744504e-06),
#  ('n07695742', 'pretzel', 2.7207784e-06),
#  ('n03967562', 'plow', 2.6733271e-06),
#  ('n02783161', 'ballpoint', 2.6587786e-06),
#  ('n03924679', 'photocopier', 2.6180123e-06),
#  ('n07614500', 'ice_cream', 2.5803654e-06),
#  ('n07734744', 'mushroom', 2.559716e-06),
#  ('n03417042', 'garbage_truck', 2.556425e-06),
#  ('n02236044', 'mantis', 2.5501936e-06),
#  ('n03776460', 'mobile_home', 2.5348816e-06),
#  ('n04479046', 'trench_coat', 2.5216107e-06),
#  ('n03444034', 'go-kart', 2.512882e-06),
#  ('n03785016', 'moped', 2.4824055e-06),
#  ('n01990800', 'isopod', 2.4752567e-06),
#  ('n02018795', 'bustard', 2.3846983e-06),
#  ('n04258138', 'solar_dish', 2.3730713e-06),
#  ('n04277352', 'spindle', 2.368886e-06),
#  ('n03218198', 'dogsled', 2.341388e-06),
#  ('n02116738', 'African_hunting_dog', 2.332827e-06),
#  ('n07697537', 'hotdog', 2.3293592e-06),
#  ('n02423022', 'gazelle', 2.3249559e-06),
#  ('n04423845', 'thimble', 2.3189925e-06),
#  ('n02025239', 'ruddy_turnstone', 2.316464e-06),
#  ('n03337140', 'file', 2.3032203e-06),
#  ('n01739381', 'vine_snake', 2.2904067e-06),
#  ('n02892767', 'brassiere', 2.278418e-06),
#  ('n04330267', 'stove', 2.2730833e-06),
#  ('n01860187', 'black_swan', 2.2729466e-06),
#  ('n03710721', 'maillot', 2.2531367e-06),
#  ('n01632458', 'spotted_salamander', 2.2522386e-06),
#  ('n07753275', 'pineapple', 2.2331435e-06),
#  ('n02007558', 'flamingo', 2.1972055e-06),
#  ('n02174001', 'rhinoceros_beetle', 2.1917328e-06),
#  ('n01774750', 'tarantula', 2.1765584e-06),
#  ('n01630670', 'common_newt', 2.1750914e-06),
#  ('n12267677', 'acorn', 2.1228886e-06),
#  ('n04597913', 'wooden_spoon', 2.0856298e-06),
#  ('n04039381', 'racket', 2.0844109e-06),
#  ('n02128385', 'leopard', 2.0747664e-06),
#  ('n07930864', 'cup', 2.0691152e-06),
#  ('n03935335', 'piggy_bank', 2.0641937e-06),
#  ('n04204238', 'shopping_basket', 2.050497e-06),
#  ('n07711569', 'mashed_potato', 2.0333177e-06),
#  ('n01735189', 'garter_snake', 2.0125556e-06),
#  ('n09472597', 'volcano', 1.9956467e-06),
#  ('n01608432', 'kite', 1.9948818e-06),
#  ('n01917289', 'brain_coral', 1.9849833e-06),
#  ('n04325704', 'stole', 1.984709e-06),
#  ('n03534580', 'hoopskirt', 1.9826014e-06),
#  ('n02264363', 'lacewing', 1.9667693e-06),
#  ('n03467068', 'guillotine', 1.92924e-06),
#  ('n03400231', 'frying_pan', 1.9261386e-06),
#  ('n02091635', 'otterhound', 1.9213062e-06),
#  ('n03733805', 'measuring_cup', 1.8978704e-06),
#  ('n01774384', 'black_widow', 1.8879473e-06),
#  ('n04442312', 'toaster', 1.886306e-06),
#  ('n02099429', 'curly-coated_retriever', 1.8845492e-06),
#  ('n09835506', 'ballplayer', 1.8784735e-06),
#  ('n02790996', 'barbell', 1.8746938e-06),
#  ('n03761084', 'microwave', 1.8727585e-06),
#  ('n02837789', 'bikini', 1.8664075e-06),
#  ('n03124170', 'cowboy_hat', 1.8596862e-06),
#  ('n07871810', 'meat_loaf', 1.8576902e-06),
#  ('n03208938', 'disk_brake', 1.8565125e-06),
#  ('n06874185', 'traffic_light', 1.8517895e-06),
#  ('n02130308', 'cheetah', 1.8446564e-06),
#  ('n02787622', 'banjo', 1.8396845e-06),
#  ('n02841315', 'binoculars', 1.8392723e-06),
#  ('n09256479', 'coral_reef', 1.8296937e-06),
#  ('n04370456', 'sweatshirt', 1.8288493e-06),
#  ('n01910747', 'jellyfish', 1.816409e-06),
#  ('n02018207', 'American_coot', 1.7956343e-06),
#  ('n03379051', 'football_helmet', 1.7924143e-06),
#  ('n03197337', 'digital_watch', 1.7869066e-06),
#  ('n02009229', 'little_blue_heron', 1.7687569e-06),
#  ('n01631663', 'eft', 1.7519939e-06),
#  ('n04023962', 'punching_bag', 1.746787e-06),
#  ('n02100583', 'vizsla', 1.7324563e-06),
#  ('n07802026', 'hay', 1.7100499e-06),
#  ('n01558993', 'robin', 1.6931829e-06),
#  ('n03710637', 'maillot', 1.6927356e-06),
#  ('n04209239', 'shower_curtain', 1.6843763e-06),
#  ('n04501370', 'turnstile', 1.6839781e-06),
#  ('n07715103', 'cauliflower', 1.6778064e-06),
#  ('n03814639', 'neck_brace', 1.6736577e-06),
#  ('n03216828', 'dock', 1.657766e-06),
#  ('n03425413', 'gas_pump', 1.6577154e-06),
#  ('n03956157', 'planetarium', 1.6443038e-06),
#  ('n02417914', 'ibex', 1.6431343e-06),
#  ('n03837869', 'obelisk', 1.6310643e-06),
#  ('n02281406', 'sulphur_butterfly', 1.6256848e-06),
#  ('n04286575', 'spotlight', 1.6247596e-06),
#  ('n04596742', 'wok', 1.6111027e-06),
#  ('n03617480', 'kimono', 1.6058459e-06),
#  ('n03775546', 'mixing_bowl', 1.5958278e-06),
#  ('n03950228', 'pitcher', 1.5660412e-06),
#  ('n01843383', 'toucan', 1.54625e-06),
#  ('n02963159', 'cardigan', 1.5452152e-06),
#  ('n03657121', 'lens_cap', 1.5361834e-06),
#  ('n04162706', 'seat_belt', 1.5328044e-06),
#  ('n04550184', 'wardrobe', 1.5216419e-06),
#  ('n03857828', 'oscilloscope', 1.5145017e-06),
#  ('n04153751', 'screw', 1.4941204e-06),
#  ('n02259212', 'leafhopper', 1.484693e-06),
#  ('n03930630', 'pickup', 1.4331576e-06),
#  ('n03792972', 'mountain_tent', 1.4252169e-06),
#  ('n04090263', 'rifle', 1.4250851e-06),
#  ('n02088466', 'bloodhound', 1.4203227e-06),
#  ('n11879895', 'rapeseed', 1.4111379e-06),
#  ('n02643566', 'lionfish', 1.4064327e-06),
#  ('n04328186', 'stopwatch', 1.4044263e-06),
#  ('n01728920', 'ringneck_snake', 1.3842873e-06),
#  ('n03476684', 'hair_slide', 1.3758903e-06),
#  ('n02206856', 'bee', 1.3686702e-06),
#  ('n02492660', 'howler_monkey', 1.3406792e-06),
#  ('n01978455', 'rock_crab', 1.3100259e-06),
#  ('n01697457', 'African_crocodile', 1.309274e-06),
#  ('n03729826', 'matchstick', 1.3034087e-06),
#  ('n03259280', 'Dutch_oven', 1.3017006e-06),
#  ('n03788365', 'mosquito_net', 1.2998448e-06),
#  ('n03424325', 'gasmask', 1.2988856e-06),
#  ('n04086273', 'revolver', 1.2956826e-06),
#  ('n03888257', 'parachute', 1.2951057e-06),
#  ('n04229816', 'ski_mask', 1.2837936e-06),
#  ('n02749479', 'assault_rifle', 1.2778999e-06),
#  ('n01592084', 'chickadee', 1.2767243e-06),
#  ('n01820546', 'lorikeet', 1.2759089e-06),
#  ('n04252225', 'snowplow', 1.2721836e-06),
#  ('n03095699', 'container_ship', 1.2633167e-06),
#  ('n04111531', 'rotisserie', 1.2419848e-06),
#  ('n07745940', 'strawberry', 1.2410542e-06),
#  ('n03598930', 'jigsaw_puzzle', 1.2384319e-06),
#  ('n07932039', 'eggnog', 1.2375735e-06),
#  ('n03673027', 'liner', 1.2332754e-06),
#  ('n03980874', 'poncho', 1.2276124e-06),
#  ('n01641577', 'bullfrog', 1.2275515e-06),
#  ('n02843684', 'birdhouse', 1.2224777e-06),
#  ('n04579145', 'whiskey_jug', 1.2043574e-06),
#  ('n04026417', 'purse', 1.1878121e-06),
#  ('n01775062', 'wolf_spider', 1.1855726e-06),
#  ('n04254120', 'soap_dispenser', 1.1835244e-06),
#  ('n04515003', 'upright', 1.1742951e-06),
#  ('n03045698', 'cloak', 1.171425e-06),
#  ('n03920288', 'Petri_dish', 1.167527e-06),
#  ('n01629819', 'European_fire_salamander', 1.1535949e-06),
#  ('n03873416', 'paddle', 1.1510178e-06),
#  ('n03874599', 'padlock', 1.149412e-06),
#  ('n03720891', 'maraca', 1.1389499e-06),
#  ('n01644373', 'tree_frog', 1.1283452e-06),
#  ('n02087394', 'Rhodesian_ridgeback', 1.1133005e-06),
#  ('n01770393', 'scorpion', 1.1127433e-06),
#  ('n01560419', 'bulbul', 1.1078217e-06),
#  ('n10565667', 'scuba_diver', 1.1057108e-06),
#  ('n02999410', 'chain', 1.085269e-06),
#  ('n02794156', 'barometer', 1.0775527e-06),
#  ('n06785654', 'crossword_puzzle', 1.0735421e-06),
#  ('n02895154', 'breastplate', 1.071609e-06),
#  ('n02690373', 'airliner', 1.0478168e-06),
#  ('n04147183', 'schooner', 1.0443003e-06),
#  ('n04548362', 'wallet', 1.0401457e-06),
#  ('n02397096', 'warthog', 1.0365579e-06),
#  ('n02165456', 'ladybug', 1.0331481e-06),
#  ('n04552348', 'warplane', 1.0292813e-06),
#  ('n02927161', 'butcher_shop', 1.0290555e-06),
#  ('n01537544', 'indigo_bunting', 1.0261351e-06),
#  ('n03388043', 'fountain', 1.0244348e-06),
#  ('n01518878', 'ostrich', 1.0240695e-06),
#  ('n03902125', 'pay-phone', 1.0223091e-06),
#  ('n04347754', 'submarine', 1.0173179e-06),
#  ('n03372029', 'flute', 1.0145053e-06),
#  ('n04251144', 'snorkel', 1.0098845e-06),
#  ('n03792782', 'mountain_bike', 1.006213e-06),
#  ('n02027492', 'red-backed_sandpiper', 1.0059895e-06),
#  ('n07760859', 'custard_apple', 1.0054447e-06),
#  ('n03954731', 'plane', 1.0037442e-06),
#  ('n03724870', 'mask', 1.0023466e-06),
#  ('n03770439', 'miniskirt', 9.69785e-07),
#  ('n02701002', 'ambulance', 9.597352e-07),
#  ('n03124043', 'cowboy_boot', 9.4379317e-07),
#  ('n01855032', 'red-breasted_merganser', 9.434592e-07),
#  ('n07717556', 'butternut_squash', 9.4104297e-07),
#  ('n02128925', 'jaguar', 9.399702e-07),
#  ('n04041544', 'radio', 9.318649e-07),
#  ('n07873807', 'pizza', 9.210022e-07),
#  ('n07613480', 'trifle', 9.1940416e-07),
#  ('n07742313', 'Granny_Smith', 9.1585025e-07),
#  ('n04264628', 'space_bar', 9.000302e-07),
#  ('n02823750', 'beer_glass', 8.871326e-07),
#  ('n02815834', 'beaker', 8.8251267e-07),
#  ('n04125021', 'safe', 8.8068566e-07),
#  ('n07768694', 'pomegranate', 8.750597e-07),
#  ('n01824575', 'coucal', 8.676299e-07),
#  ('n03131574', 'crib', 8.5504087e-07),
#  ('n01978287', 'Dungeness_crab', 8.464627e-07),
#  ('n04259630', 'sombrero', 8.424697e-07),
#  ('n02981792', 'catamaran', 8.4129675e-07),
#  ('n02017213', 'European_gallinule', 8.384006e-07),
#  ('n04456115', 'torch', 8.325888e-07),
#  ('n03584254', 'iPod', 8.30435e-07),
#  ('n01704323', 'triceratops', 8.281541e-07),
#  ('n03769881', 'minibus', 8.259158e-07),
#  ('n02480855', 'gorilla', 8.1808287e-07),
#  ('n04612504', 'yawl', 8.157223e-07),
#  ('n01531178', 'goldfinch', 8.024036e-07),
#  ('n01742172', 'boa_constrictor', 8.0168604e-07),
#  ('n01688243', 'frilled_lizard', 8.0041184e-07),
#  ('n03868863', 'oxygen_mask', 7.928284e-07),
#  ('n04613696', 'yurt', 7.856464e-07),
#  ('n03884397', 'panpipe', 7.845481e-07),
#  ('n03697007', 'lumbermill', 7.8312854e-07),
#  ('n02835271', 'bicycle-built-for-two', 7.6731595e-07),
#  ('n04366367', 'suspension_bridge', 7.62588e-07),
#  ('n12768682', 'buckeye', 7.596751e-07),
#  ('n03584829', 'iron', 7.5551856e-07),
#  ('n03347037', 'fire_screen', 7.532337e-07),
#  ('n02481823', 'chimpanzee', 7.495518e-07),
#  ('n01795545', 'black_grouse', 7.460082e-07),
#  ('n04065272', 'recreational_vehicle', 7.44586e-07),
#  ('n07716906', 'spaghetti_squash', 7.423044e-07),
#  ('n07718747', 'artichoke', 7.4189813e-07),
#  ('n02229544', 'cricket', 7.41756e-07),
#  ('n03196217', 'digital_clock', 7.3859786e-07),
#  ('n02834397', 'bib', 7.336878e-07),
#  ('n02071294', 'killer_whale', 7.3321775e-07),
#  ('n04238763', 'slide_rule', 7.330199e-07),
#  ('n02066245', 'grey_whale', 7.3062813e-07),
#  ('n07753592', 'banana', 7.285338e-07),
#  ('n03445924', 'golfcart', 7.2831983e-07),
#  ('n03602883', 'joystick', 7.2594685e-07),
#  ('n04335435', 'streetcar', 7.240013e-07),
#  ('n02480495', 'orangutan', 7.211649e-07),
#  ('n03443371', 'goblet', 7.1404486e-07),
#  ('n02870880', 'bookcase', 7.1306835e-07),
#  ('n04398044', 'teapot', 7.1101283e-07),
#  ('n02483708', 'siamang', 6.953747e-07),
#  ('n07693725', 'bagel', 6.953528e-07),
#  ('n02489166', 'proboscis_monkey', 6.873291e-07),
#  ('n02129165', 'lion', 6.862215e-07),
#  ('n02256656', 'cicada', 6.8247925e-07),
#  ('n04525305', 'vending_machine', 6.807579e-07),
#  ('n03742115', 'medicine_chest', 6.677768e-07),
#  ('n07684084', 'French_loaf', 6.566682e-07),
#  ('n03908618', 'pencil_box', 6.539154e-07),
#  ('n01930112', 'nematode', 6.4412006e-07),
#  ('n04355933', 'sunglass', 6.372153e-07),
#  ('n03220513', 'dome', 6.370622e-07),
#  ('n02966687', "carpenter's_kit", 6.3592285e-07),
#  ('n03461385', 'grocery_store', 6.3053375e-07),
#  ('n04346328', 'stupa', 6.183063e-07),
#  ('n01829413', 'hornbill', 6.157266e-07),
#  ('n01980166', 'fiddler_crab', 6.111261e-07),
#  ('n01818515', 'macaw', 6.092982e-07),
#  ('n03063689', 'coffeepot', 6.0067396e-07),
#  ('n04525038', 'velvet', 5.964902e-07),
#  ('n03388183', 'fountain_pen', 5.9144764e-07),
#  ('n01770081', 'harvestman', 5.9010284e-07),
#  ('n01622779', 'great_grey_owl', 5.8729177e-07),
#  ('n04392985', 'tape_player', 5.8316175e-07),
#  ('n02002724', 'black_stork', 5.778956e-07),
#  ('n01955084', 'chiton', 5.77532e-07),
#  ('n02415577', 'bighorn', 5.6519116e-07),
#  ('n03733131', 'maypole', 5.637286e-07),
#  ('n03982430', 'pool_table', 5.6302525e-07),
#  ('n02013706', 'limpkin', 5.613921e-07),
#  ('n04372370', 'switch', 5.586166e-07),
#  ('n02276258', 'admiral', 5.4725274e-07),
#  ('n02398521', 'hippopotamus', 5.4164616e-07),
#  ('n02437312', 'Arabian_camel', 5.3920684e-07),
#  ('n03594945', 'jeep', 5.391405e-07),
#  ('n02791270', 'barbershop', 5.3833287e-07),
#  ('n04192698', 'shield', 5.350862e-07),
#  ('n01532829', 'house_finch', 5.349556e-07),
#  ('n01644900', 'tailed_frog', 5.2832144e-07),
#  ('n04487394', 'trombone', 5.270528e-07),
#  ('n02980441', 'castle', 5.2315676e-07),
#  ('n03977966', 'police_van', 5.131559e-07),
#  ('n03495258', 'harp', 5.116776e-07),
#  ('n04523525', 'vault', 5.086233e-07),
#  ('n02992529', 'cellular_telephone', 5.080609e-07),
#  ('n03763968', 'military_uniform', 5.0675055e-07),
#  ('n04200800', 'shoe_shop', 5.0628194e-07),
#  ('n03929660', 'pick', 5.03472e-07),
#  ('n03290653', 'entertainment_center', 5.01404e-07),
#  ('n02776631', 'bakery', 4.9128835e-07),
#  ('n03496892', 'harvester', 4.8760825e-07),
#  ('n02859443', 'boathouse', 4.8015255e-07),
#  ('n02028035', 'redshank', 4.7908674e-07),
#  ('n04540053', 'volleyball', 4.708197e-07),
#  ('n02791124', 'barber_chair', 4.6389715e-07),
#  ('n03494278', 'harmonica', 4.6170447e-07),
#  ('n13037406', 'gyromitra', 4.605944e-07),
#  ('n04252077', 'snowmobile', 4.5882763e-07),
#  ('n03485407', 'hand-held_computer', 4.577136e-07),
#  ('n04461696', 'tow_truck', 4.544285e-07),
#  ('n04141076', 'sax', 4.5428118e-07),
#  ('n03992509', "potter's_wheel", 4.535734e-07),
#  ('n03179701', 'desk', 4.4919508e-07),
#  ('n04356056', 'sunglasses', 4.4687923e-07),
#  ('n04542943', 'waffle_iron', 4.4631147e-07),
#  ('n03759954', 'microphone', 4.441066e-07),
#  ('n01968897', 'chambered_nautilus', 4.4387076e-07),
#  ('n07730033', 'cardoon', 4.3811878e-07),
#  ('n02089078', 'black-and-tan_coonhound', 4.3605834e-07),
#  ('n02865351', 'bolo_tie', 4.354296e-07),
#  ('n04486054', 'triumphal_arch', 4.3437942e-07),
#  ('n03100240', 'convertible', 4.319665e-07),
#  ('n03063599', 'coffee_mug', 4.3158397e-07),
#  ('n03637318', 'lampshade', 4.1971452e-07),
#  ('n02391049', 'zebra', 4.174459e-07),
#  ('n03721384', 'marimba', 4.1534005e-07),
#  ('n04273569', 'speedboat', 4.1384948e-07),
#  ('n02403003', 'ox', 4.1373067e-07),
#  ('n03016953', 'chiffonier', 4.1109752e-07),
#  ('n01694178', 'African_chameleon', 4.1091562e-07),
#  ('n02807133', 'bathing_cap', 4.0216997e-07),
#  ('n04179913', 'sewing_machine', 4.0181806e-07),
#  ('n04146614', 'school_bus', 3.9952084e-07),
#  ('n03384352', 'forklift', 3.988565e-07),
#  ('n01530575', 'brambling', 3.9318732e-07),
#  ('n02730930', 'apron', 3.8932325e-07),
#  ('n03527444', 'holster', 3.8929872e-07),
#  ('n02804610', 'bassoon', 3.8536183e-07),
#  ('n03777754', 'modem', 3.8309e-07),
#  ('n01983481', 'American_lobster', 3.8154042e-07),
#  ('n03961711', 'plate_rack', 3.8097502e-07),
#  ('n02389026', 'sorrel', 3.801791e-07),
#  ('n04443257', 'tobacco_shop', 3.7970298e-07),
#  ('n06359193', 'web_site', 3.781812e-07),
#  ('n03042490', 'cliff_dwelling', 3.7810221e-07),
#  ('n03529860', 'home_theater', 3.77227e-07),
#  ('n04485082', 'tripod', 3.770914e-07),
#  ('n02817516', 'bearskin', 3.7551703e-07),
#  ('n03394916', 'French_horn', 3.7456135e-07),
#  ('n03476991', 'hair_spray', 3.7441276e-07),
#  ('n04149813', 'scoreboard', 3.6865305e-07),
#  ('n03000247', 'chain_mail', 3.6797866e-07),
#  ('n04263257', 'soup_bowl', 3.6429697e-07),
#  ('n02965783', 'car_mirror', 3.6370784e-07),
#  ('n03388549', 'four-poster', 3.6332827e-07),
#  ('n04467665', 'trailer_truck', 3.6012142e-07),
#  ('n02871525', 'bookshop', 3.594767e-07),
#  ('n04532670', 'viaduct', 3.5816643e-07),
#  ('n03459775', 'grille', 3.5796563e-07),
#  ('n04209133', 'shower_cap', 3.569225e-07),
#  ('n02607072', 'anemone_fish', 3.5605154e-07),
#  ('n03709823', 'mailbag', 3.5388632e-07),
#  ('n03662601', 'lifeboat', 3.5318874e-07),
#  ('n04127249', 'safety_pin', 3.5235777e-07),
#  ('n03032252', 'cinema', 3.5220054e-07),
#  ('n02408429', 'water_buffalo', 3.4910758e-07),
#  ('n07753113', 'fig', 3.4261916e-07),
#  ('n04584207', 'wig', 3.4090638e-07),
#  ('n07717410', 'acorn_squash', 3.4031132e-07),
#  ('n04005630', 'prison', 3.3917374e-07),
#  ('n01981276', 'king_crab', 3.3766392e-07),
#  ('n07892512', 'red_wine', 3.31625e-07),
#  ('n04536866', 'violin', 3.299115e-07),
#  ('n03249569', 'drum', 3.216093e-07),
#  ('n07720875', 'bell_pepper', 3.1869564e-07),
#  ('n03895866', 'passenger_car', 3.1752765e-07),
#  ('n03866082', 'overskirt', 3.1636606e-07),
#  ('n02704792', 'amphibian', 3.1481005e-07),
#  ('n03691459', 'loudspeaker', 3.132868e-07),
#  ('n03841143', 'odometer', 3.0415168e-07),
#  ('n04591157', 'Windsor_tie', 3.035258e-07),
#  ('n02793495', 'barn', 3.0312196e-07),
#  ('n01984695', 'spiny_lobster', 3.0178302e-07),
#  ('n02190166', 'fly', 2.9541025e-07),
#  ('n04311004', 'steel_arch_bridge', 2.9394945e-07),
#  ('n02782093', 'balloon', 2.9101733e-07),
#  ('n02910353', 'buckle', 2.9074715e-07),
#  ('n03180011', 'desktop_computer', 2.8886967e-07),
#  ('n03692522', 'loupe', 2.85029e-07),
#  ('n03868242', 'oxcart', 2.804048e-07),
#  ('n03530642', 'honeycomb', 2.7606387e-07),
#  ('n02939185', 'caldron', 2.7527597e-07),
#  ('n04285008', 'sports_car', 2.70933e-07),
#  ('n02410509', 'bison', 2.67679e-07),
#  ('n01773549', 'barn_spider', 2.6371907e-07),
#  ('n02966193', 'carousel', 2.628972e-07),
#  ('n07583066', 'guacamole', 2.626326e-07),
#  ('n03706229', 'magnetic_compass', 2.602376e-07),
#  ('n03201208', 'dining_table', 2.57191e-07),
#  ('n03314780', 'face_powder', 2.5525162e-07),
#  ('n02988304', 'CD_player', 2.5369238e-07),
#  ('n03018349', 'china_cabinet', 2.5364014e-07),
#  ('n02606052', 'rock_beauty', 2.5216454e-07),
#  ('n03590841', "jack-o'-lantern", 2.4870675e-07),
#  ('n03075370', 'combination_lock', 2.4479652e-07),
#  ('n04483307', 'trimaran', 2.4217954e-07),
#  ('n02916936', 'bulletproof_vest', 2.4005416e-07),
#  ('n02802426', 'basketball', 2.3936948e-07),
#  ('n07579787', 'plate', 2.3463872e-07),
#  ('n04548280', 'wall_clock', 2.3454142e-07),
#  ('n03908714', 'pencil_sharpener', 2.2570066e-07),
#  ('n02825657', 'bell_cote', 2.2562575e-07),
#  ('n03062245', 'cocktail_shaker', 2.2423168e-07),
#  ('n04044716', 'radio_telescope', 2.2278371e-07),
#  ('n04136333', 'sarong', 2.2098972e-07),
#  ('n02011460', 'bittern', 2.1877244e-07),
#  ('n07836838', 'chocolate_sauce', 2.1707821e-07),
#  ('n03595614', 'jersey', 2.1653318e-07),
#  ('n03492542', 'hard_disc', 2.1415342e-07),
#  ('n04389033', 'tank', 2.1245606e-07),
#  ('n03661043', 'library', 2.1072452e-07),
#  ('n07920052', 'espresso', 2.0946125e-07),
#  ('n03452741', 'grand_piano', 2.0578892e-07),
#  ('n02672831', 'accordion', 2.0555844e-07),
#  ('n02667093', 'abaya', 2.0111865e-07),
#  ('n03838899', 'oboe', 1.9970298e-07),
#  ('n04380533', 'table_lamp', 1.9857436e-07),
#  ('n03538406', 'horse_cart', 1.9847437e-07),
#  ('n07747607', 'orange', 1.9781093e-07),
#  ('n03874293', 'paddlewheel', 1.9764818e-07),
#  ('n02666196', 'abacus', 1.9709312e-07),
#  ('n02165105', 'tiger_beetle', 1.9704537e-07),
#  ('n02226429', 'grasshopper', 1.9550933e-07),
#  ('n04465501', 'tractor', 1.9206585e-07),
#  ('n03447721', 'gong', 1.9034196e-07),
#  ('n07749582', 'lemon', 1.8640694e-07),
#  ('n02167151', 'ground_beetle', 1.8570731e-07),
#  ('n04487081', 'trolleybus', 1.8531966e-07),
#  ('n04311174', 'steel_drum', 1.813369e-07),
#  ('n12620546', 'hip', 1.8084641e-07),
#  ('n03788195', 'mosque', 1.794293e-07),
#  ('n03676483', 'lipstick', 1.7742128e-07),
#  ('n01773797', 'garden_spider', 1.7480143e-07),
#  ('n01773157', 'black_and_gold_garden_spider', 1.7437851e-07),
#  ('n02978881', 'cassette', 1.7424668e-07),
#  ('n04009552', 'projector', 1.7409037e-07),
#  ('n03028079', 'church', 1.7152954e-07),
#  ('n02277742', 'ringlet', 1.6945033e-07),
#  ('n02840245', 'binder', 1.6625022e-07),
#  ('n07248320', 'book_jacket', 1.5873015e-07),
#  ('n03109150', 'corkscrew', 1.5767479e-07),
#  ('n04428191', 'thresher', 1.5724412e-07),
#  ('n04462240', 'toyshop', 1.5625064e-07),
#  ('n04019541', 'puck', 1.560877e-07),
#  ('n03110669', 'cornet', 1.5483963e-07),
#  ('n04310018', 'steam_locomotive', 1.5481719e-07),
#  ('n03017168', 'chime', 1.5108193e-07),
#  ('n04275548', 'spider_web', 1.5028941e-07),
#  ('n04069434', 'reflex_camera', 1.4895653e-07),
#  ('n04532106', 'vestment', 1.4339827e-07),
#  ('n02769748', 'backpack', 1.4339143e-07),
#  ('n03599486', 'jinrikisha', 1.4314345e-07),
#  ('n07697313', 'cheeseburger', 1.4202895e-07),
#  ('n04243546', 'slot', 1.3880529e-07),
#  ('n02279972', 'monarch', 1.3812655e-07),
#  ('n01828970', 'bee_eater', 1.3739032e-07),
#  ('n03877845', 'palace', 1.3547509e-07),
#  ('n02168699', 'long-horned_beetle', 1.3303988e-07),
#  ('n03814906', 'necklace', 1.309106e-07),
#  ('n03393912', 'freight_car', 1.3085644e-07),
#  ('n03916031', 'perfume', 1.2223478e-07),
#  ('n02699494', 'altar', 1.2042156e-07),
#  ('n02177972', 'weevil', 1.1903892e-07),
#  ('n03976467', 'Polaroid_camera', 1.16178754e-07),
#  ('n02708093', 'analog_clock', 1.1589114e-07),
#  ('n03345487', 'fire_engine', 1.1485216e-07),
#  ('n04562935', 'water_tower', 1.0922271e-07),
#  ('n03240683', 'drilling_platform', 1.08365505e-07),
#  ('n03854065', 'organ', 1.0697214e-07),
#  ('n03187595', 'dial_telephone', 1.05531754e-07),
#  ('n07875152', 'potpie', 1.0322445e-07),
#  ('n03126707', 'crane', 9.6825225e-08),
#  ('n03447447', 'gondola', 9.483128e-08),
#  ('n02033041', 'dowitcher', 9.241172e-08),
#  ('n02504013', 'Indian_elephant', 8.93363e-08),
#  ('n03272010', 'electric_guitar', 8.925787e-08),
#  ('n01843065', 'jacamar', 8.82785e-08),
#  ('n02979186', 'cassette_player', 8.390008e-08),
#  ('n03544143', 'hourglass', 7.8314e-08),
#  ('n04458633', 'totem_pole', 7.614379e-08),
#  ('n04266014', 'space_shuttle', 7.360218e-08),
#  ('n02676566', 'acoustic_guitar', 7.349269e-08),
#  ('n03781244', 'monastery', 7.179667e-08),
#  ('n07831146', 'carbonara', 6.933976e-08),
#  ('n03272562', 'electric_locomotive', 6.8863834e-08),
#  ('n02169497', 'leaf_beetle', 6.8366774e-08),
#  ('n03146219', 'cuirass', 6.809563e-08),
#  ('n04505470', 'typewriter_keyboard', 6.700181e-08),
#  ('n03929855', 'pickelhaube', 6.612895e-08),
#  ('n03777568', 'Model_T', 5.9222625e-08),
#  ('n01768244', 'trilobite', 5.7956537e-08),
#  ('n04296562', 'stage', 5.2894784e-08),
#  ('n02281787', 'lycaenid', 5.286498e-08),
#  ('n04429376', 'throne', 4.9458105e-08),
#  ('n12057211', "yellow_lady's_slipper", 4.936697e-08),
#  ('n04081281', 'restaurant', 4.8362107e-08),
#  ('n02268443', 'dragonfly', 4.7655657e-08),
#  ('n03478589', 'half_track', 4.75864e-08),
#  ('n03947888', 'pirate', 4.692528e-08),
#  ('n02992211', 'cello', 4.5234977e-08),
#  ('n07565083', 'menu', 4.432593e-08),
#  ('n02669723', 'academic_gown', 4.3269523e-08),
#  ('n04418357', 'theater_curtain', 4.2066556e-08),
#  ('n07590611', 'hot_pot', 4.0485894e-08),
#  ('n07584110', 'consomme', 3.9026354e-08),
#  ('n03089624', 'confectionery', 3.4990606e-08),
#  ('n06596364', 'comic_book', 2.9654254e-08),
#  ('n02422699', 'impala', 2.8543687e-08),
#  ('n02268853', 'damselfly', 2.7532781e-08),
#  ('n03297495', 'espresso_maker', 2.539435e-08),
#  ('n02422106', 'hartebeest', 2.2251395e-08),
#  ('n02504458', 'African_elephant', 1.4811404e-08),
#  ('n01871265', 'tusker', 1.2258142e-08)]
